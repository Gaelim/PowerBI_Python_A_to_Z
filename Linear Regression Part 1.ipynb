# %%
#Load in the essential Libraries
import pandas as pd
import numpy as np
#Load in the visual libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read in the dataset with pandas and check the top 5 rows
dataset= pd.read_csv('Desktop/Data/50_startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Create a statistical summary
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#create a correlation table
dataset.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
#look at the data types
dataset.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
#look for null values
dataset.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
#count the string categories
dataset['State'].value_counts()
# Out:
# California    17
# New York      17
# Florida       16
# Name: State, dtype: int64

# %%
#encode the string or state columns
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0  165349.20       136897.80        471784.10  192261.83              0
# 1  162597.70       151377.59        443898.53  191792.06              0
# 2  153441.51       101145.55        407934.54  191050.39              1
# 3  144372.41       118671.85        383199.62  182901.99              0
# 4  142107.34        91391.77        366168.42  166187.94              1
#
#    State_New York
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
# 
from sklearn.model_selection  import train_test_split
features = ['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']
target = ['Profit']

X= dataset[features]
y=dataset[target]

# %%
X.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida',
#        'State_New York'],
#       dtype='object')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_scaled =  scale.fit_transform(X_train)
X_test_scaled =scale.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin  = LinearRegression()
lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 59040.82984170386

# %%
y_pred = lin.predict(X_test)

# %%
print(f"The R2 score is {r2_score(y_test,y_pred):.3f} and root mean squar error is {np.sqrt(mean_squared_error(y_test,y_pred)):.2f}")
# Out:
# The R2 score is 0.843 and root mean squar error is 14498.91

# %%
y_pred2 = pd.DataFrame(y_pred)

# %%
y_pred2
# Out:
#                 0
# 0    60617.935806
# 1    68287.394185
# 2    70122.522481
# 3   127435.767881
# 4    72007.902167
# 5   150128.188282
# 6    52717.449566
# 7    62558.915403
# 8    66849.349162
# 9   172830.656505
# 10  133713.992600
# 11   39330.682691
# 12   95687.201017

# %%
y_test2 = y_test.reset_index()

# %%
compared = pd.merge(y_test2,y_pred2,left_index=True,right_index=True)
compared.columns=['index','Profit','Prediction']
compared
# Out:
#     index     Profit     Prediction
# 0      38   81229.06   60617.935806
# 1      41   77798.83   68287.394185
# 2      36   90708.19   70122.522481
# 3      12  141585.52  127435.767881
# 4      40   78239.91   72007.902167
# 5      14  132602.65  150128.188282
# 6      43   69758.98   52717.449566
# 7      44   65200.33   62558.915403
# 8      42   71498.49   66849.349162
# 9       3  182901.99  172830.656505
# 10     10  146121.95  133713.992600
# 11     45   64926.08   39330.682691
# 12     30   99937.59   95687.201017

# %%
compared['difference'] =  compared['Profit'] - compared['Prediction']
compared
# Out:
#     index     Profit     Prediction    difference
# 0      38   81229.06   60617.935806  20611.124194
# 1      41   77798.83   68287.394185   9511.435815
# 2      36   90708.19   70122.522481  20585.667519
# 3      12  141585.52  127435.767881  14149.752119
# 4      40   78239.91   72007.902167   6232.007833
# 5      14  132602.65  150128.188282 -17525.538282
# 6      43   69758.98   52717.449566  17041.530434
# 7      44   65200.33   62558.915403   2641.414597
# 45    1000.23       124153.04          1903.93   64926.08              0
# 46    1315.46       115816.21        297114.46   49490.75              1
# 47       0.00       135426.92             0.00   42559.73              0
# 48     542.05        51743.15             0.00   35673.41              0
# 49       0.00       116983.80         45173.06   14681.40              0
#
#     State_New York    Predictions
# 0                1  193336.538466
# 1                0  194469.174518
# 2                0  182804.933477
# 3                1  172830.656505
# 4                0  171892.274399
# 5                1  161469.809405
# 6                0  161783.639514
# 7                0  160815.773492
# 8                1  150534.998448
# 9                0  156788.087106
# 10               0  133713.992600
# 11               0  135751.491369
# 12               0  127435.767881
# 13               0  128555.814413
# 14               0  150128.188282
# 15               1  143899.266129
# 16               0  116816.345789
# 17               1  127501.348757
# 18               0  126799.336405
# 19               1  112738.349791
# 20               0  116212.722896
# 21               1  114038.281207
# 22               0  111819.698341
# 23               0  106242.155914
# 24               1  108311.826537
# 25               0  101973.237034
# 26               0  108424.547858
# 27               1  110000.914104
# 28               0  100180.083815
# 29               1   97794.092052
# 30               0   95687.201017
# 31               1   93438.396075
# 32               0   98341.615232
# 33               0   93431.062753
# 34               0   88377.965685
# 35               1   83387.257456
# 36               0   70122.522481
# 37               0   85548.286577
# 38               1   60617.935806
# 39               0   80342.158906
# 40               0   72007.902167
# 41               0   68287.394185
# 42               0   66849.349162
# 43               1   52717.449566
# 44               0   62558.915403
# 45               1   39330.682691
# 46               0   49219.793546
# 47               0   42664.224143
# 48               1   38592.401576
# 49               0   43824.486818

# %%
dataset.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit  \
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000
# State_Florida     0.105711        0.010493         0.205685  0.116244
# State_New York    0.039068        0.005145        -0.033670  0.031368
# Predictions       0.997698        0.227999         0.759259  0.973945
#
#                  State_Florida  State_New York  Predictions
# R&D Spend             0.105711        0.039068     0.997698
# Administration        0.010493        0.005145     0.227999
# Marketing Spend       0.205685       -0.033670     0.759259
# Profit                0.116244        0.031368     0.973945
# State_Florida         1.000000       -0.492366     0.110459
# State_New York       -0.492366        1.000000     0.000614
# Predictions           0.110459        0.000614     1.000000

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
lin.fit(X_train,y_train)
y_pred5 = lin.predict(X_test)

# %%
r2_score(y_test,y_pred5)
# Out:
# 0.983977173500061

# %%
y_pred5
# Out:
# array([[100565.47616075],
#        [ 97360.15729461],
#        [111328.23320131],
#        [ 57430.65089983],
#        [ 73437.75124291],
#        [187355.22579465],
#        [ 59688.14762513],
#        [ 88811.83743621],
#        [101019.94739807],
#        [ 44915.06472206],
#        [ 87301.0131954 ],
#        [191898.1177319 ],
#        [129537.44612064]])

# %%
y_test
# Out:
#        Profit
# 25  107404.34
# 32   97427.84
# 26  105733.54
# 46   49490.75
# 40   78239.91
# 1   191792.06
# 43   69758.98
# 37   89949.14
# 29  101004.64
# 47   42559.73
# 34   96712.80
# 0   192261.83
# 17  125370.37
